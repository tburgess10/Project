# %%
import sqlite3

class AtterbergLimitsModule:
    def __init__(self, db_connection):
        self.db_connection_path = db_connection
        self.conn = None

    def __enter__(self):
        self.conn = sqlite3.connect(self.db_connection_path)
        print(f"Connected to database: {self.db_connection_path}")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        if self.conn:
            self.conn.close()

    def fetch_all_sample_ids(self):
        """
        Fetch all SampleID values from the database.
        """
        query = "SELECT DISTINCT SampleID FROM AtterbergLimitResults"  # Adjust table name
        cursor = self.conn.cursor()
        cursor.execute(query)
        sample_ids = [row[0] for row in cursor.fetchall()]
        return sample_ids


    def fetch_data(self, sample_id):
        """Fetches the Atterberg limits data for a given SampleID, skipping rows with invalid data types."""
        cursor = self.conn.cursor()
        query = """
        SELECT SampleID, LiquidLimitTareWeight, LiquidLimitWeight,
               LiquidLimitDryWeight, LiquidLimitNumberOfBlows, LiquidLimitNotObtained,
               PlasticLimitTareWeight, PlasticLimitWetWeight, PlasticLimitDryWeight,
               PlasticLimitNotObtained
        FROM AtterbergLimitResults
        WHERE SampleID = ?
        """
        cursor.execute(query, (sample_id,))
        row = cursor.fetchone()
    
        if row:
            try:
                # Convert values to the appropriate types
                data = {
                    'SampleID': row[0],
                    'LiquidLimitTareWeight': float(row[1]),
                    'LiquidLimitWeight': float(row[2]),
                    'LiquidLimitDryWeight': float(row[3]),
                    'LiquidLimitNumberOfBlows': int(row[4]),
                    'LiquidLimitNotObtained': str(row[5]).strip().upper() if row[5] is not None else None,
                    'PlasticLimitTareWeight': float(row[6]),
                    'PlasticLimitWetWeight': float(row[7]),
                    'PlasticLimitDryWeight': float(row[8]),
                    'PlasticLimitNotObtained': str(row[9]).strip().upper() if row[9] is not None else None,
                }
                print(f"Fetched and processed data: {data}")
                return data
            except (TypeError, ValueError) as e:
                print(f"Skipping row for SampleID {sample_id} due to invalid data: {e}")
                return None
        else:
            print(f"No valid data found for SampleID {sample_id}.")
            return None


    def validate_atterberg_data(self, data):
        """ Validates input data for Atterberg limits testing. """
        if not data.get('LiquidLimitNotObtained'):
            required_fields = ['LiquidLimitTareWeight', 'LiquidLimitWeight', 'LiquidLimitDryWeight', 'LiquidLimitNumberOfBlows']
            for field in required_fields:
                if field not in data or data[field] is None:
                    return False, f"{field} is required for Liquid Limit."
            if data['LiquidLimitWeight'] <= data['LiquidLimitDryWeight']:
                return False, "Liquid Limit Wet Weight must be greater than Dry Weight."
        
        if not data.get('PlasticLimitNotObtained'):
            required_fields = ['PlasticLimitTareWeight', 'PlasticLimitWetWeight', 'PlasticLimitDryWeight']
            for field in required_fields:
                if field not in data or data[field] is None:
                    return False, f"{field} is required for Plastic Limit."
            if data['PlasticLimitWetWeight'] <= data['PlasticLimitDryWeight']:
                return False, "Plastic Limit Wet Weight must be greater than Dry Weight."
        
        return True, ""

    def calculate_percent_moisture(self, tare_weight, wet_weight, dry_weight):
        if tare_weight is None or wet_weight is None or dry_weight is None:
            print("Invalid input for percent moisture calculation.")
            return None
        water_weight = wet_weight - dry_weight
        dry_soil_weight = dry_weight - tare_weight
        if dry_soil_weight == 0:
            print("Error: Dry soil weight is zero.")
            return None
        percent_moisture = round((water_weight / dry_soil_weight) * 100, 2)
        print(f"Percent Moisture: {percent_moisture}%")
        return percent_moisture

    def calculate_liquid_limit(self, percent_moisture, blows):
        if blows is None or blows <= 0 or percent_moisture is None:
            print("Invalid input for liquid limit calculation.")
            return None
        correction_factor = (blows / 25) ** 0.121
        liquid_limit = round(percent_moisture * correction_factor, 2)
        print(f"Liquid Limit: {liquid_limit}")
        return liquid_limit

    def calculate_plastic_limit(self, percent_moisture):
        if percent_moisture is None:
            print("Invalid input for plastic limit calculation.")
            return None
        print(f"Plastic Limit: {percent_moisture}")
        return percent_moisture

    def calculate_plasticity_index(self, liquid_limit, plastic_limit):
        print(f"Calculating Plasticity Index: LiquidLimit={liquid_limit}, PlasticLimit={plastic_limit}")
        if liquid_limit is None or plastic_limit is None:
            print("Invalid input for plasticity index calculation.")
            return None
        plasticity_index = round(liquid_limit - plastic_limit, 2)
        print(f"Plasticity Index: {plasticity_index}")
        return plasticity_index      

    def store_atterberg_results(self, data):
        """ Updates the Atterberg Limits results in the SQLite database. """
        cursor = self.conn.cursor()
        query = """
        UPDATE AtterbergLimitResults
        SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
        WHERE SampleID = ?
        """
        values = (
            data.get('LiquidLimit'),
            data.get('PlasticLimit'),
            data.get('PlasticityIndex'),
            data.get('SampleID'),
        )
        print(f"Executing SQL: {query} with values {values}")  # Debug log
        cursor.execute(query, values)
        self.conn.commit()
        print("Database updated successfully.")

    def process_atterberg_data(self, data):
        is_valid, error_message = self.validate_atterberg_data(data)
        if not is_valid:
            print(f"Validation failed: {error_message}")
            return {"success": False, "message": error_message}
        print("Validation passed.")
        print(f"LiquidLimitNotObtained: {data.get('LiquidLimitNotObtained')}")
        print(f"PlasticLimitNotObtained: {data.get('PlasticLimitNotObtained')}")
    
        liquid_limit = None
        plastic_limit = None
        plasticity_index = None
    
        # Calculate Liquid Limit
        if data.get('LiquidLimitNotObtained') == 'FALSE':  # Explicitly check string value
            percent_moisture_liquid = self.calculate_percent_moisture(
                data['LiquidLimitTareWeight'],
                data['LiquidLimitWeight'],
                data['LiquidLimitDryWeight']
            )
            print(f"Percent Moisture for Liquid Limit: {percent_moisture_liquid}")
            liquid_limit = self.calculate_liquid_limit(percent_moisture_liquid, data['LiquidLimitNumberOfBlows'])
            print(f"Calculated Liquid Limit: {liquid_limit}")
    
        # Calculate Plastic Limit
        if data.get('PlasticLimitNotObtained') == 'FALSE':  # Explicitly check string value
            print("Calculating Plastic Limit...")
            percent_moisture_plastic = self.calculate_percent_moisture(
                data['PlasticLimitTareWeight'],
                data['PlasticLimitWetWeight'],
                data['PlasticLimitDryWeight']
            )
            print(f"Percent Moisture for Plastic Limit: {percent_moisture_plastic}")
            plastic_limit = self.calculate_plastic_limit(percent_moisture_plastic)
            print(f"Calculated Plastic Limit: {plastic_limit}")
    
        # Calculate Plasticity Index
        if liquid_limit is not None and plastic_limit is not None:
            plasticity_index = self.calculate_plasticity_index(liquid_limit, plastic_limit)
            print(f"Calculated Plasticity Index: {plasticity_index}")
    
        try:
            self.store_atterberg_results({
                'SampleID': data.get('SampleID'),
                'LiquidLimit': liquid_limit,
                'PlasticLimit': plastic_limit,
                'PlasticityIndex': plasticity_index
            })
            return {"success": True, "message": "Data processed successfully"}
        except Exception as e:
            print(f"Error storing results: {e}")
            return {"success": False, "message": str(e)}
# Out:
# Connected to database: Soil_framework.sqlite
# Fetched and processed data: {'SampleID': 6, 'LiquidLimitTareWeight': 15.14, 'LiquidLimitWeight': 37.49, 'LiquidLimitDryWeight': 32.51, 'LiquidLimitNumberOfBlows': 27, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 15.15, 'PlasticLimitWetWeight': 25.32, 'PlasticLimitDryWeight': 23.55, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 28.67%
# Percent Moisture for Liquid Limit: 28.67
# Liquid Limit: 28.94
# Calculated Liquid Limit: 28.94
# Calculating Plastic Limit...
# Percent Moisture: 21.07%
# Percent Moisture for Plastic Limit: 21.07
# Plastic Limit: 21.07
# Calculated Plastic Limit: 21.07
# Calculating Plasticity Index: LiquidLimit=28.94, PlasticLimit=21.07
# Plasticity Index: 7.87
# Calculated Plasticity Index: 7.87
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (28.94, 21.07, 7.87, 6)
# Database updated successfully.
# {'success': True, 'message': 'Data processed successfully'}

# %%
### This can be used to iterate through the ID's just uncomment the loop in the beginning of script.

# %%
db_path = 'Soil_framework.sqlite'

with AtterbergLimitsModule(db_path) as atterberg_module:
    # Fetch all available sample IDs
    sample_ids = atterberg_module.fetch_all_sample_ids()
    for sample_id in sample_ids:
        print(f"Processing SampleID {sample_id}...")
        data = atterberg_module.fetch_data(sample_id)
        if data:
            result = atterberg_module.process_atterberg_data(data)
            print(f"Result for SampleID {sample_id}: {result}")
        else:
            print(f"No data found for SampleID {sample_id}")
# Out:
# Connected to database: Soil_framework.sqlite
# Processing SampleID SampleID...
# Skipping row for SampleID SampleID due to invalid data: could not convert string to float: 'LiquidLimitTareWeight'
# No data found for SampleID SampleID
# Processing SampleID 2...
# Fetched and processed data: {'SampleID': 2, 'LiquidLimitTareWeight': 15.22, 'LiquidLimitWeight': 29.55, 'LiquidLimitDryWeight': 24.07, 'LiquidLimitNumberOfBlows': 26, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 15.21, 'PlasticLimitWetWeight': 24.9, 'PlasticLimitDryWeight': 22.86, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 61.92%
# Percent Moisture for Liquid Limit: 61.92
# Liquid Limit: 62.21
# Calculated Liquid Limit: 62.21
# Calculating Plastic Limit...
# Percent Moisture: 26.67%
# Percent Moisture for Plastic Limit: 26.67
# Plastic Limit: 26.67
# Calculated Plastic Limit: 26.67
# Calculating Plasticity Index: LiquidLimit=62.21, PlasticLimit=26.67
# Plasticity Index: 35.54
# Calculated Plasticity Index: 35.54
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (62.21, 26.67, 35.54, 2)
# Database updated successfully.
# Result for SampleID 2: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 3...
# Fetched and processed data: {'SampleID': 3, 'LiquidLimitTareWeight': 15.1, 'LiquidLimitWeight': 29.6, 'LiquidLimitDryWeight': 24.3, 'LiquidLimitNumberOfBlows': 25, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 15.1, 'PlasticLimitWetWeight': 24.5, 'PlasticLimitDryWeight': 22.7, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 57.61%
# Percent Moisture for Liquid Limit: 57.61
# Liquid Limit: 57.61
# Calculated Liquid Limit: 57.61
# Calculating Plastic Limit...
# Percent Moisture: 23.68%
# Percent Moisture for Plastic Limit: 23.68
# Plastic Limit: 23.68
# Calculated Plastic Limit: 23.68
# Calculating Plasticity Index: LiquidLimit=57.61, PlasticLimit=23.68
# Plasticity Index: 33.93
# Calculated Plasticity Index: 33.93
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (57.61, 23.68, 33.93, 3)
# Database updated successfully.
# Result for SampleID 3: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 5...
# Fetched and processed data: {'SampleID': 5, 'LiquidLimitTareWeight': 15.22, 'LiquidLimitWeight': 33.97, 'LiquidLimitDryWeight': 29.93, 'LiquidLimitNumberOfBlows': 23, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 15.2, 'PlasticLimitWetWeight': 25.27, 'PlasticLimitDryWeight': 23.58, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 27.46%
# Percent Moisture for Liquid Limit: 27.46
# Liquid Limit: 27.18
# Calculated Liquid Limit: 27.18
# Calculating Plastic Limit...
# Percent Moisture: 20.17%
# Percent Moisture for Plastic Limit: 20.17
# Plastic Limit: 20.17
# Calculated Plastic Limit: 20.17
# Calculating Plasticity Index: LiquidLimit=27.18, PlasticLimit=20.17
# Plasticity Index: 7.01
# Calculated Plasticity Index: 7.01
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (27.18, 20.17, 7.01, 5)
# Database updated successfully.
# Result for SampleID 5: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 6...
# Fetched and processed data: {'SampleID': 6, 'LiquidLimitTareWeight': 15.14, 'LiquidLimitWeight': 37.49, 'LiquidLimitDryWeight': 32.51, 'LiquidLimitNumberOfBlows': 27, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 15.15, 'PlasticLimitWetWeight': 25.32, 'PlasticLimitDryWeight': 23.55, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 28.67%
# Percent Moisture for Liquid Limit: 28.67
# Liquid Limit: 28.94
# Calculated Liquid Limit: 28.94
# Calculating Plastic Limit...
# Percent Moisture: 21.07%
# Percent Moisture for Plastic Limit: 21.07
# Plastic Limit: 21.07
# Calculated Plastic Limit: 21.07
# Calculating Plasticity Index: LiquidLimit=28.94, PlasticLimit=21.07
# Plasticity Index: 7.87
# Calculated Plasticity Index: 7.87
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (28.94, 21.07, 7.87, 6)
# Database updated successfully.
# Result for SampleID 6: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 19...
# Skipping row for SampleID 19 due to invalid data: could not convert string to float: ''
# No data found for SampleID 19
# Processing SampleID 31...
# Skipping row for SampleID 31 due to invalid data: could not convert string to float: ''
# No data found for SampleID 31
# Processing SampleID 32...
# Skipping row for SampleID 32 due to invalid data: could not convert string to float: ''
# No data found for SampleID 32
# Processing SampleID 34...
# Fetched and processed data: {'SampleID': 34, 'LiquidLimitTareWeight': 10.81, 'LiquidLimitWeight': 27.92, 'LiquidLimitDryWeight': 20.64, 'LiquidLimitNumberOfBlows': 23, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.82, 'PlasticLimitWetWeight': 20.47, 'PlasticLimitDryWeight': 18.05, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 74.06%
# Percent Moisture for Liquid Limit: 74.06
# Liquid Limit: 73.32
# Calculated Liquid Limit: 73.32
# Calculating Plastic Limit...
# Percent Moisture: 33.47%
# Percent Moisture for Plastic Limit: 33.47
# Plastic Limit: 33.47
# Calculated Plastic Limit: 33.47
# Calculating Plasticity Index: LiquidLimit=73.32, PlasticLimit=33.47
# Plasticity Index: 39.85
# Calculated Plasticity Index: 39.85
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (73.32, 33.47, 39.85, 34)
# Database updated successfully.
# Result for SampleID 34: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 35...
# Fetched and processed data: {'SampleID': 35, 'LiquidLimitTareWeight': 11.02, 'LiquidLimitWeight': 28.5, 'LiquidLimitDryWeight': 24.02, 'LiquidLimitNumberOfBlows': 23, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.92, 'PlasticLimitWetWeight': 20.83, 'PlasticLimitDryWeight': 19.2, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 34.46%
# Percent Moisture for Liquid Limit: 34.46
# Liquid Limit: 34.11
# Calculated Liquid Limit: 34.11
# Calculating Plastic Limit...
# Percent Moisture: 19.69%
# Percent Moisture for Plastic Limit: 19.69
# Plastic Limit: 19.69
# Calculated Plastic Limit: 19.69
# Calculating Plasticity Index: LiquidLimit=34.11, PlasticLimit=19.69
# Plasticity Index: 14.42
# Calculated Plasticity Index: 14.42
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (34.11, 19.69, 14.42, 35)
# Database updated successfully.
# Result for SampleID 35: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 37...
# Fetched and processed data: {'SampleID': 37, 'LiquidLimitTareWeight': 10.89, 'LiquidLimitWeight': 31.06, 'LiquidLimitDryWeight': 23.22, 'LiquidLimitNumberOfBlows': 23, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.87, 'PlasticLimitWetWeight': 20.6, 'PlasticLimitDryWeight': 17.83, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 63.58%
# Percent Moisture for Liquid Limit: 63.58
# Liquid Limit: 62.94
# Calculated Liquid Limit: 62.94
# Calculating Plastic Limit...
# Percent Moisture: 39.8%
# Percent Moisture for Plastic Limit: 39.8
# Plastic Limit: 39.8
# Calculated Plastic Limit: 39.8
# Calculating Plasticity Index: LiquidLimit=62.94, PlasticLimit=39.8
# Plasticity Index: 23.14
# Calculated Plasticity Index: 23.14
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (62.94, 39.8, 23.14, 37)
# Database updated successfully.
# Result for SampleID 37: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 38...
# Fetched and processed data: {'SampleID': 38, 'LiquidLimitTareWeight': 10.99, 'LiquidLimitWeight': 27.51, 'LiquidLimitDryWeight': 21.61, 'LiquidLimitNumberOfBlows': 26, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.97, 'PlasticLimitWetWeight': 20.63, 'PlasticLimitDryWeight': 18.27, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 55.56%
# Percent Moisture for Liquid Limit: 55.56
# Liquid Limit: 55.82
# Calculated Liquid Limit: 55.82
# Calculating Plastic Limit...
# Percent Moisture: 32.33%
# Percent Moisture for Plastic Limit: 32.33
# Plastic Limit: 32.33
# Calculated Plastic Limit: 32.33
# Calculating Plasticity Index: LiquidLimit=55.82, PlasticLimit=32.33
# Plasticity Index: 23.49
# Calculated Plasticity Index: 23.49
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (55.82, 32.33, 23.49, 38)
# Database updated successfully.
# Result for SampleID 38: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 40...
# Skipping row for SampleID 40 due to invalid data: could not convert string to float: ''
# No data found for SampleID 40
# Processing SampleID 41...
# Fetched and processed data: {'SampleID': 41, 'LiquidLimitTareWeight': 10.93, 'LiquidLimitWeight': 31.36, 'LiquidLimitDryWeight': 25.9, 'LiquidLimitNumberOfBlows': 29, 'LiquidLimitNotObtained': 'TRUE', 'PlasticLimitTareWeight': 10.96, 'PlasticLimitWetWeight': 20.63, 'PlasticLimitDryWeight': 19.1, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: TRUE
# PlasticLimitNotObtained: FALSE
# Calculating Plastic Limit...
# Percent Moisture: 18.8%
# Percent Moisture for Plastic Limit: 18.8
# Plastic Limit: 18.8
# Calculated Plastic Limit: 18.8
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (None, 18.8, None, 41)
# Database updated successfully.
# Result for SampleID 41: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 42...
# Fetched and processed data: {'SampleID': 42, 'LiquidLimitTareWeight': 10.97, 'LiquidLimitWeight': 29.24, 'LiquidLimitDryWeight': 25.2, 'LiquidLimitNumberOfBlows': 21, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.88, 'PlasticLimitWetWeight': 20.94, 'PlasticLimitDryWeight': 19.41, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 28.39%
# Percent Moisture for Liquid Limit: 28.39
# Liquid Limit: 27.8
# Calculated Liquid Limit: 27.8
# Calculating Plastic Limit...
# Percent Moisture: 17.94%
# Percent Moisture for Plastic Limit: 17.94
# Plastic Limit: 17.94
# Calculated Plastic Limit: 17.94
# Calculating Plasticity Index: LiquidLimit=27.8, PlasticLimit=17.94
# Plasticity Index: 9.86
# Calculated Plasticity Index: 9.86
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (27.8, 17.94, 9.86, 42)
# Database updated successfully.
# Result for SampleID 42: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 44...
# Fetched and processed data: {'SampleID': 44, 'LiquidLimitTareWeight': 10.99, 'LiquidLimitWeight': 29.93, 'LiquidLimitDryWeight': 21.95, 'LiquidLimitNumberOfBlows': 27, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.92, 'PlasticLimitWetWeight': 20.38, 'PlasticLimitDryWeight': 17.69, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 72.81%
# Percent Moisture for Liquid Limit: 72.81
# Liquid Limit: 73.49
# Calculated Liquid Limit: 73.49
# Calculating Plastic Limit...
# Percent Moisture: 39.73%
# Percent Moisture for Plastic Limit: 39.73
# Plastic Limit: 39.73
# Calculated Plastic Limit: 39.73
# Calculating Plasticity Index: LiquidLimit=73.49, PlasticLimit=39.73
# Plasticity Index: 33.76
# Calculated Plasticity Index: 33.76
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (73.49, 39.73, 33.76, 44)
# Database updated successfully.
# Result for SampleID 44: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 45...
# Fetched and processed data: {'SampleID': 45, 'LiquidLimitTareWeight': 10.87, 'LiquidLimitWeight': 30.02, 'LiquidLimitDryWeight': 22.7, 'LiquidLimitNumberOfBlows': 29, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.96, 'PlasticLimitWetWeight': 20.48, 'PlasticLimitDryWeight': 18.59, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 61.88%
# Percent Moisture for Liquid Limit: 61.88
# Liquid Limit: 63.0
# Calculated Liquid Limit: 63.0
# Calculating Plastic Limit...
# Percent Moisture: 24.77%
# Percent Moisture for Plastic Limit: 24.77
# Plastic Limit: 24.77
# Calculated Plastic Limit: 24.77
# Calculating Plasticity Index: LiquidLimit=63.0, PlasticLimit=24.77
# Plasticity Index: 38.23
# Calculated Plasticity Index: 38.23
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (63.0, 24.77, 38.23, 45)
# Database updated successfully.
# Result for SampleID 45: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 47...
# Fetched and processed data: {'SampleID': 47, 'LiquidLimitTareWeight': 10.8, 'LiquidLimitWeight': 28.39, 'LiquidLimitDryWeight': 21.82, 'LiquidLimitNumberOfBlows': 21, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.47, 'PlasticLimitWetWeight': 19.95, 'PlasticLimitDryWeight': 18.11, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 59.62%
# Percent Moisture for Liquid Limit: 59.62
# Liquid Limit: 58.38
# Calculated Liquid Limit: 58.38
# Calculating Plastic Limit...
# Percent Moisture: 24.08%
# Percent Moisture for Plastic Limit: 24.08
# Plastic Limit: 24.08
# Calculated Plastic Limit: 24.08
# Calculating Plasticity Index: LiquidLimit=58.38, PlasticLimit=24.08
# Plasticity Index: 34.3
# Calculated Plasticity Index: 34.3
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (58.38, 24.08, 34.3, 47)
# Database updated successfully.
# Result for SampleID 47: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 48...
# Skipping row for SampleID 48 due to invalid data: could not convert string to float: ''
# No data found for SampleID 48
# Processing SampleID 49...
# Skipping row for SampleID 49 due to invalid data: could not convert string to float: ''
# No data found for SampleID 49
# Processing SampleID 50...
# Skipping row for SampleID 50 due to invalid data: could not convert string to float: ''
# No data found for SampleID 50
# Processing SampleID 51...
# Skipping row for SampleID 51 due to invalid data: could not convert string to float: ''
# No data found for SampleID 51
# Processing SampleID 66...
# Fetched and processed data: {'SampleID': 66, 'LiquidLimitTareWeight': 10.85, 'LiquidLimitWeight': 26.23, 'LiquidLimitDryWeight': 20.64, 'LiquidLimitNumberOfBlows': 24, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.88, 'PlasticLimitWetWeight': 20.46, 'PlasticLimitDryWeight': 18.15, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 57.1%
# Percent Moisture for Liquid Limit: 57.1
# Liquid Limit: 56.82
# Calculated Liquid Limit: 56.82
# Calculating Plastic Limit...
# Percent Moisture: 31.77%
# Percent Moisture for Plastic Limit: 31.77
# Plastic Limit: 31.77
# Calculated Plastic Limit: 31.77
# Calculating Plasticity Index: LiquidLimit=56.82, PlasticLimit=31.77
# Plasticity Index: 25.05
# Calculated Plasticity Index: 25.05
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (56.82, 31.77, 25.05, 66)
# Database updated successfully.
# Result for SampleID 66: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 70...
# Fetched and processed data: {'SampleID': 70, 'LiquidLimitTareWeight': 10.85, 'LiquidLimitWeight': 30.7, 'LiquidLimitDryWeight': 25.59, 'LiquidLimitNumberOfBlows': 25, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.85, 'PlasticLimitWetWeight': 20.72, 'PlasticLimitDryWeight': 19.18, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 34.67%
# Percent Moisture for Liquid Limit: 34.67
# Liquid Limit: 34.67
# Calculated Liquid Limit: 34.67
# Calculating Plastic Limit...
# Percent Moisture: 18.49%
# Percent Moisture for Plastic Limit: 18.49
# Plastic Limit: 18.49
# Calculated Plastic Limit: 18.49
# Calculating Plasticity Index: LiquidLimit=34.67, PlasticLimit=18.49
# Plasticity Index: 16.18
# Calculated Plasticity Index: 16.18
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (34.67, 18.49, 16.18, 70)
# Database updated successfully.
# Result for SampleID 70: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 71...
# Skipping row for SampleID 71 due to invalid data: could not convert string to float: ''
# No data found for SampleID 71
# Processing SampleID 79...
# Fetched and processed data: {'SampleID': 79, 'LiquidLimitTareWeight': 10.94, 'LiquidLimitWeight': 28.13, 'LiquidLimitDryWeight': 22.27, 'LiquidLimitNumberOfBlows': 27, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.84, 'PlasticLimitWetWeight': 20.35, 'PlasticLimitDryWeight': 18.42, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 51.72%
# Percent Moisture for Liquid Limit: 51.72
# Liquid Limit: 52.2
# Calculated Liquid Limit: 52.2
# Calculating Plastic Limit...
# Percent Moisture: 25.46%
# Percent Moisture for Plastic Limit: 25.46
# Plastic Limit: 25.46
# Calculated Plastic Limit: 25.46
# Calculating Plasticity Index: LiquidLimit=52.2, PlasticLimit=25.46
# Plasticity Index: 26.74
# Calculated Plasticity Index: 26.74
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (52.2, 25.46, 26.74, 79)
# Database updated successfully.
# Result for SampleID 79: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 80...
# Fetched and processed data: {'SampleID': 80, 'LiquidLimitTareWeight': 10.45, 'LiquidLimitWeight': 26.57, 'LiquidLimitDryWeight': 21.65, 'LiquidLimitNumberOfBlows': 24, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.75, 'PlasticLimitWetWeight': 20.41, 'PlasticLimitDryWeight': 18.69, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 43.93%
# Percent Moisture for Liquid Limit: 43.93
# Liquid Limit: 43.71
# Calculated Liquid Limit: 43.71
# Calculating Plastic Limit...
# Percent Moisture: 21.66%
# Percent Moisture for Plastic Limit: 21.66
# Plastic Limit: 21.66
# Calculated Plastic Limit: 21.66
# Calculating Plasticity Index: LiquidLimit=43.71, PlasticLimit=21.66
# Plasticity Index: 22.05
# Calculated Plasticity Index: 22.05
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (43.71, 21.66, 22.05, 80)
# Database updated successfully.
# Result for SampleID 80: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 85...
# Fetched and processed data: {'SampleID': 85, 'LiquidLimitTareWeight': 10.92, 'LiquidLimitWeight': 27.08, 'LiquidLimitDryWeight': 21.97, 'LiquidLimitNumberOfBlows': 24, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.83, 'PlasticLimitWetWeight': 20.71, 'PlasticLimitDryWeight': 18.64, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 46.24%
# Percent Moisture for Liquid Limit: 46.24
# Liquid Limit: 46.01
# Calculated Liquid Limit: 46.01
# Calculating Plastic Limit...
# Percent Moisture: 26.5%
# Percent Moisture for Plastic Limit: 26.5
# Plastic Limit: 26.5
# Calculated Plastic Limit: 26.5
# Calculating Plasticity Index: LiquidLimit=46.01, PlasticLimit=26.5
# Plasticity Index: 19.51
# Calculated Plasticity Index: 19.51
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (46.01, 26.5, 19.51, 85)
# Database updated successfully.
# Result for SampleID 85: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 86...
# Skipping row for SampleID 86 due to invalid data: could not convert string to float: ''
# No data found for SampleID 86
# Processing SampleID 87...
# Skipping row for SampleID 87 due to invalid data: could not convert string to float: ''
# No data found for SampleID 87
# Processing SampleID 88...
# Fetched and processed data: {'SampleID': 88, 'LiquidLimitTareWeight': 10.45, 'LiquidLimitWeight': 27.18, 'LiquidLimitDryWeight': 22.47, 'LiquidLimitNumberOfBlows': 26, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.85, 'PlasticLimitWetWeight': 20.34, 'PlasticLimitDryWeight': 18.53, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 39.18%
# Percent Moisture for Liquid Limit: 39.18
# Liquid Limit: 39.37
# Calculated Liquid Limit: 39.37
# Calculating Plastic Limit...
# Percent Moisture: 23.57%
# Percent Moisture for Plastic Limit: 23.57
# Plastic Limit: 23.57
# Calculated Plastic Limit: 23.57
# Calculating Plasticity Index: LiquidLimit=39.37, PlasticLimit=23.57
# Plasticity Index: 15.8
# Calculated Plasticity Index: 15.8
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (39.37, 23.57, 15.8, 88)
# Database updated successfully.
# Result for SampleID 88: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 90...
# Fetched and processed data: {'SampleID': 90, 'LiquidLimitTareWeight': 14.65, 'LiquidLimitWeight': 36.02, 'LiquidLimitDryWeight': 31.08, 'LiquidLimitNumberOfBlows': 26, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 15.06, 'PlasticLimitWetWeight': 24.54, 'PlasticLimitDryWeight': 22.89, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 30.07%
# Percent Moisture for Liquid Limit: 30.07
# Liquid Limit: 30.21
# Calculated Liquid Limit: 30.21
# Calculating Plastic Limit...
# Percent Moisture: 21.07%
# Percent Moisture for Plastic Limit: 21.07
# Plastic Limit: 21.07
# Calculated Plastic Limit: 21.07
# Calculating Plasticity Index: LiquidLimit=30.21, PlasticLimit=21.07
# Plasticity Index: 9.14
# Calculated Plasticity Index: 9.14
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (30.21, 21.07, 9.14, 90)
# Database updated successfully.
# Result for SampleID 90: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 91...
# Fetched and processed data: {'SampleID': 91, 'LiquidLimitTareWeight': 10.9, 'LiquidLimitWeight': 28.79, 'LiquidLimitDryWeight': 21.45, 'LiquidLimitNumberOfBlows': 27, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.44, 'PlasticLimitWetWeight': 19.76, 'PlasticLimitDryWeight': 17.82, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 69.57%
# Percent Moisture for Liquid Limit: 69.57
# Liquid Limit: 70.22
# Calculated Liquid Limit: 70.22
# Calculating Plastic Limit...
# Percent Moisture: 26.29%
# Percent Moisture for Plastic Limit: 26.29
# Plastic Limit: 26.29
# Calculated Plastic Limit: 26.29
# Calculating Plasticity Index: LiquidLimit=70.22, PlasticLimit=26.29
# Plasticity Index: 43.93
# Calculated Plasticity Index: 43.93
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (70.22, 26.29, 43.93, 91)
# Database updated successfully.
# Result for SampleID 91: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 92...
# Fetched and processed data: {'SampleID': 92, 'LiquidLimitTareWeight': 10.82, 'LiquidLimitWeight': 28.05, 'LiquidLimitDryWeight': 21.65, 'LiquidLimitNumberOfBlows': 28, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.75, 'PlasticLimitWetWeight': 20.51, 'PlasticLimitDryWeight': 18.45, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 59.1%
# Percent Moisture for Liquid Limit: 59.1
# Liquid Limit: 59.92
# Calculated Liquid Limit: 59.92
# Calculating Plastic Limit...
# Percent Moisture: 26.75%
# Percent Moisture for Plastic Limit: 26.75
# Plastic Limit: 26.75
# Calculated Plastic Limit: 26.75
# Calculating Plasticity Index: LiquidLimit=59.92, PlasticLimit=26.75
# Plasticity Index: 33.17
# Calculated Plasticity Index: 33.17
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (59.92, 26.75, 33.17, 92)
# Database updated successfully.
# Result for SampleID 92: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 93...
# Fetched and processed data: {'SampleID': 93, 'LiquidLimitTareWeight': 10.95, 'LiquidLimitWeight': 26.88, 'LiquidLimitDryWeight': 21.48, 'LiquidLimitNumberOfBlows': 29, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.77, 'PlasticLimitWetWeight': 20.56, 'PlasticLimitDryWeight': 18.58, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 51.28%
# Percent Moisture for Liquid Limit: 51.28
# Liquid Limit: 52.21
# Calculated Liquid Limit: 52.21
# Calculating Plastic Limit...
# Percent Moisture: 25.35%
# Percent Moisture for Plastic Limit: 25.35
# Plastic Limit: 25.35
# Calculated Plastic Limit: 25.35
# Calculating Plasticity Index: LiquidLimit=52.21, PlasticLimit=25.35
# Plasticity Index: 26.86
# Calculated Plasticity Index: 26.86
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (52.21, 25.35, 26.86, 93)
# Database updated successfully.
# Result for SampleID 93: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 94...
# Fetched and processed data: {'SampleID': 94, 'LiquidLimitTareWeight': 10.89, 'LiquidLimitWeight': 29.7, 'LiquidLimitDryWeight': 23.71, 'LiquidLimitNumberOfBlows': 29, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.84, 'PlasticLimitWetWeight': 20.73, 'PlasticLimitDryWeight': 19.0, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 46.72%
# Percent Moisture for Liquid Limit: 46.72
# Liquid Limit: 47.57
# Calculated Liquid Limit: 47.57
# Calculating Plastic Limit...
# Percent Moisture: 21.2%
# Percent Moisture for Plastic Limit: 21.2
# Plastic Limit: 21.2
# Calculated Plastic Limit: 21.2
# Calculating Plasticity Index: LiquidLimit=47.57, PlasticLimit=21.2
# Plasticity Index: 26.37
# Calculated Plasticity Index: 26.37
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (47.57, 21.2, 26.37, 94)
# Database updated successfully.
# Result for SampleID 94: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 95...
# Fetched and processed data: {'SampleID': 95, 'LiquidLimitTareWeight': 10.95, 'LiquidLimitWeight': 28.74, 'LiquidLimitDryWeight': 22.19, 'LiquidLimitNumberOfBlows': 25, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.86, 'PlasticLimitWetWeight': 20.74, 'PlasticLimitDryWeight': 18.55, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 58.27%
# Percent Moisture for Liquid Limit: 58.27
# Liquid Limit: 58.27
# Calculated Liquid Limit: 58.27
# Calculating Plastic Limit...
# Percent Moisture: 28.48%
# Percent Moisture for Plastic Limit: 28.48
# Plastic Limit: 28.48
# Calculated Plastic Limit: 28.48
# Calculating Plasticity Index: LiquidLimit=58.27, PlasticLimit=28.48
# Plasticity Index: 29.79
# Calculated Plasticity Index: 29.79
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (58.27, 28.48, 29.79, 95)
# Database updated successfully.
# Result for SampleID 95: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 96...
# Fetched and processed data: {'SampleID': 96, 'LiquidLimitTareWeight': 10.94, 'LiquidLimitWeight': 31.69, 'LiquidLimitDryWeight': 23.72, 'LiquidLimitNumberOfBlows': 21, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.75, 'PlasticLimitWetWeight': 20.5, 'PlasticLimitDryWeight': 18.54, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 62.36%
# Percent Moisture for Liquid Limit: 62.36
# Liquid Limit: 61.06
# Calculated Liquid Limit: 61.06
# Calculating Plastic Limit...
# Percent Moisture: 25.16%
# Percent Moisture for Plastic Limit: 25.16
# Plastic Limit: 25.16
# Calculated Plastic Limit: 25.16
# Calculating Plasticity Index: LiquidLimit=61.06, PlasticLimit=25.16
# Plasticity Index: 35.9
# Calculated Plasticity Index: 35.9
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (61.06, 25.16, 35.9, 96)
# Database updated successfully.
# Result for SampleID 96: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 97...
# Fetched and processed data: {'SampleID': 97, 'LiquidLimitTareWeight': 10.9, 'LiquidLimitWeight': 30.19, 'LiquidLimitDryWeight': 22.99, 'LiquidLimitNumberOfBlows': 28, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.81, 'PlasticLimitWetWeight': 20.4, 'PlasticLimitDryWeight': 18.6, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 59.55%
# Percent Moisture for Liquid Limit: 59.55
# Liquid Limit: 60.37
# Calculated Liquid Limit: 60.37
# Calculating Plastic Limit...
# Percent Moisture: 23.11%
# Percent Moisture for Plastic Limit: 23.11
# Plastic Limit: 23.11
# Calculated Plastic Limit: 23.11
# Calculating Plasticity Index: LiquidLimit=60.37, PlasticLimit=23.11
# Plasticity Index: 37.26
# Calculated Plasticity Index: 37.26
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (60.37, 23.11, 37.26, 97)
# Database updated successfully.
# Result for SampleID 97: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 98...
# Fetched and processed data: {'SampleID': 98, 'LiquidLimitTareWeight': 10.89, 'LiquidLimitWeight': 33.45, 'LiquidLimitDryWeight': 28.67, 'LiquidLimitNumberOfBlows': 28, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.81, 'PlasticLimitWetWeight': 20.92, 'PlasticLimitDryWeight': 19.4, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 26.88%
# Percent Moisture for Liquid Limit: 26.88
# Liquid Limit: 27.25
# Calculated Liquid Limit: 27.25
# Calculating Plastic Limit...
# Percent Moisture: 17.69%
# Percent Moisture for Plastic Limit: 17.69
# Plastic Limit: 17.69
# Calculated Plastic Limit: 17.69
# Calculating Plasticity Index: LiquidLimit=27.25, PlasticLimit=17.69
# Plasticity Index: 9.56
# Calculated Plasticity Index: 9.56
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (27.25, 17.69, 9.56, 98)
# Database updated successfully.
# Result for SampleID 98: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 99...
# Fetched and processed data: {'SampleID': 99, 'LiquidLimitTareWeight': 10.89, 'LiquidLimitWeight': 30.55, 'LiquidLimitDryWeight': 25.92, 'LiquidLimitNumberOfBlows': 27, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 10.8, 'PlasticLimitWetWeight': 20.61, 'PlasticLimitDryWeight': 18.79, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 30.81%
# Percent Moisture for Liquid Limit: 30.81
# Liquid Limit: 31.1
# Calculated Liquid Limit: 31.1
# Calculating Plastic Limit...
# Percent Moisture: 22.78%
# Percent Moisture for Plastic Limit: 22.78
# Plastic Limit: 22.78
# Calculated Plastic Limit: 22.78
# Calculating Plasticity Index: LiquidLimit=31.1, PlasticLimit=22.78
# Plasticity Index: 8.32
# Calculated Plasticity Index: 8.32
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (31.1, 22.78, 8.32, 99)
# Database updated successfully.
# Result for SampleID 99: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 100...
# Fetched and processed data: {'SampleID': 100, 'LiquidLimitTareWeight': 14.64, 'LiquidLimitWeight': 34.14, 'LiquidLimitDryWeight': 29.71, 'LiquidLimitNumberOfBlows': 24, 'LiquidLimitNotObtained': 'FALSE', 'PlasticLimitTareWeight': 15.05, 'PlasticLimitWetWeight': 24.24, 'PlasticLimitDryWeight': 22.56, 'PlasticLimitNotObtained': 'FALSE'}
# Validation passed.
# LiquidLimitNotObtained: FALSE
# PlasticLimitNotObtained: FALSE
# Percent Moisture: 29.4%
# Percent Moisture for Liquid Limit: 29.4
# Liquid Limit: 29.26
# Calculated Liquid Limit: 29.26
# Calculating Plastic Limit...
# Percent Moisture: 22.37%
# Percent Moisture for Plastic Limit: 22.37
# Plastic Limit: 22.37
# Calculated Plastic Limit: 22.37
# Calculating Plasticity Index: LiquidLimit=29.26, PlasticLimit=22.37
# Plasticity Index: 6.89
# Calculated Plasticity Index: 6.89
# Executing SQL:
#         UPDATE AtterbergLimitResults
#         SET LiquidLimit = ?, PlasticLimit = ?, PlasticityIndex = ?
#         WHERE SampleID = ?
#          with values (29.26, 22.37, 6.89, 100)
# Database updated successfully.
# Result for SampleID 100: {'success': True, 'message': 'Data processed successfully'}
# Processing SampleID 101...
# Skipping row for SampleID 101 due to invalid data: could not convert string to float: ''
# No data found for SampleID 101
# Processing SampleID 102...
# Skipping row for SampleID 102 due to invalid data: could not convert string to float: ''
# No data found for SampleID 102
# Processing SampleID 103...
# Skipping row for SampleID 103 due to invalid data: could not convert string to float: ''
# No data found for SampleID 103
